# %%
import pandas as pd 

# Creating the data set for footbal teams and matches
data_test = {
    "match_code": [
        201, 
        202, 
        203, 
        204, 
        205,
        206,
        207, 
        208,
        201], #201 added specifically to show an example of a non-function field (competition)
    "team_main": [
        "Real Madrid", 
        "Bayern München", 
        "Paris Saint-Germain", 
        "Liverpool",
        "Arsenal", 
        "Atlético Madrid", 
        "Newcastle", 
        "Galatasaray",
        "Real Madrid"
    ],
    "team_guest": [
        "Bayern München", 
        "Real Madrid", 
        "Arsenal", 
        "Atlético Madrid",
        "Paris Saint-Germain", 
        "Liverpool", 
        "Galatasaray", 
        "Newcastle", 
        "Bayern München"
    ],
    "competition": [
        "Champions League",     
        "Bundesliga", 
        "Premier League", 
        "Champions League",
        "Bundesliga", 
        "Premier League", 
        "Europa League", 
        "Ligue 1", 
        "Premier League"],
    "final_score": ["3-2", "2-2", "1-1", "4-0", "2-1", "1-3", "6-1", "0-3", "2-1"]
}

df_temp = pd.DataFrame(data_test) 
df_temp.to_csv("matches.csv", index=False) 
print("File 'matches.csv' has been successfully created.")
# Out:
# File 'matches.csv' has been successfully created.

# %%
def analyze_dataset(df, key_column, function_columns):
    print("\nChecking for duplicate records:")
    duplicates = df[df.duplicated()]
    if duplicates.empty:
        print("No duplicates found.")
    else:
        print("\nDuplicate records:")
        print(duplicates)

    distinct_values = []
    relationships = []

    # Verification whether the columns are function
    for col in function_columns: 
        # Identifying distinct values in the column
        unique_values = set(df[col]) 
        distinct_values.append({"col": col, "values": unique_values})

        values_per_key = df.groupby(key_column)[col].nunique() 
        problematic_values = values_per_key[values_per_key > 1] 
        relationships.append({"col": col, "is_function": len(problematic_values) == 0, "problematic_values": problematic_values})

    for v in distinct_values:
        print(f"Distinct values in column {v['col']}: {len(v['values'])}")
        print(sorted(v['values']))
        print()

    print("Function columns:")
    for r in relationships:
        if r['is_function']:
            print(f"{r['col']}")

    print() 
    print("Non-function columns:")
    for r in relationships:
        if not r['is_function']:
            print(f"{r['col']}")
        
# Downloading the file
df = pd.read_csv("matches.csv") 
print(df.head(df.size)) 
print() 

# Displaying data types
print(df.dtypes)
print() 

analyze_dataset(
    df, 
    key_column="match_code", 
    function_columns=["team_main", "team_guest", "competition", "final_score"])
# Out:
#    match_code            team_main           team_guest       competition  \
# 0         201          Real Madrid       Bayern München  Champions League
# 1         202       Bayern München          Real Madrid        Bundesliga
# 2         203  Paris Saint-Germain              Arsenal    Premier League
# 3         204            Liverpool      Atlético Madrid  Champions League
# 4         205              Arsenal  Paris Saint-Germain        Bundesliga
# 5         206      Atlético Madrid            Liverpool    Premier League
# 6         207            Newcastle          Galatasaray     Europa League
# 7         208          Galatasaray            Newcastle           Ligue 1
# 8         201          Real Madrid       Bayern München    Premier League
#
#   final_score
# 0         3-2
# 1         2-2
# 2         1-1
# 3         4-0
# 4         2-1
# 5         1-3
# 6         6-1
# 7         0-3
# 8         2-1
#
# match_code     int64
# team_main        str
# team_guest       str
# competition      str
# final_score      str
# dtype: object
#
#
# Checking for duplicate records:
# No duplicates found.
# Distinct values in column team_main: 8
# ['Arsenal', 'Atlético Madrid', 'Bayern München', 'Galatasaray', 'Liverpool', 'Newcastle', 'Paris Saint-Germain', 'Real Madrid']
#
# Distinct values in column team_guest: 8
# ['Arsenal', 'Atlético Madrid', 'Bayern München', 'Galatasaray', 'Liverpool', 'Newcastle', 'Paris Saint-Germain', 'Real Madrid']
#
# Distinct values in column competition: 5
# ['Bundesliga', 'Champions League', 'Europa League', 'Ligue 1', 'Premier League']
#
# Distinct values in column final_score: 8
# ['0-3', '1-1', '1-3', '2-1', '2-2', '3-2', '4-0', '6-1']
#
# Function columns:
# team_main
# team_guest
#
# Non-function columns:
# competition
# final_score
